# %%
import pandas as pd

df = pd.read_csv("../data/sample.csv")
print("Shape:", df.shape)
print(df.head())
print(df.describe())
# Out:
# Shape: (5, 3)
#    name  score  passed
# 0   Ali     92    True
# 1  Sara     88    True
# 2  Omar     55   False
# 3  Lina     95    True
# 4  Zaid     40   False
#            score
# count   5.000000
# mean   74.000000
# std    24.889757
# min    40.000000
# 25%    55.000000
# 50%    88.000000
# 75%    92.000000
# max    95.000000
